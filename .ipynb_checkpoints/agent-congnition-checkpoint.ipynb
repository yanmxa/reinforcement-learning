# %% [markdown]
# # Agent Cognition
#
# ### 经验规则
# ### 寻优算法
# ### Q-learning
# ### DQN

# %% [markdown]
# ## 1. 经验规则
# - 生命游戏游戏 (https://fnky.github.io/particle-life/ , https://arxiv.org/abs/1111.1567)
# - 兰顿蚂蚁
# - 谢林模型

# %%
# !python3 ./smooth-game-of-life/smoothlife.py

# %%
# !python3 ./vant.py

# %% [markdown]
# #### 谢林模型
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.寻优算法

# %% [markdown]
# - 动态规划(DP)
# - 遗传算法(GA)
# - 粒子群算法(PSO)
# - 模拟退火算法(SA)
# - 蚁群算法(ACO)
# - 自适应神经网络(SOM)
# - 禁忌搜索算法(TS)

# %% [markdown]
# #### PSO
# [visualizer](file:///Users/yanmeng/workspace/reinforcement-learning-playground/PSO-visualization/index.html)

# %% [markdown]
# #### PSO - farmer
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 3. Q-learning

# %% [markdown]
# ### Agent各要素
# - 状态state
# - 行为action
# - 环境environment
# - 回报reword
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# http://www.real-statistics.com/statistics-tables/studentized-range-q-table/

# %% [markdown]
# ## 4. DQN
# - /Users/yanmeng/workspace/reinforcement-learning-playground/DQNNaturePaper.pdf
# - https://mp.weixin.qq.com/s/7gL3lLzPaB9qdWVQRhHSNA
